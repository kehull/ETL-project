# %%
import pandas as pd

# %%
ufodata = "Resources/scrubbed_ufo.csv"
ufodf = pd.read_csv(ufodata, low_memory=False)
ufodf
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 2                     20           20 seconds
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...                  ...                  ...
# 80327                600           10 minutes
# 80328               1200           20 minutes
# 80329               1200                 hour
# 80330                  5            5 seconds
# 80331               1020           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude
# 0      29.8830556  -97.941111
# 1        29.38421  -98.581082
# 2            53.2   -2.916667
# 3      28.9783333  -96.645833
# 4      21.4180556 -157.803611
# ...           ...         ...
# 80327  36.1658333  -86.784444
# 80328  43.6136111 -116.202500
# 80329  38.2972222 -122.284444
# 80330  38.9011111  -77.265556
# 80331  35.6527778  -97.477778
#
# [80332 rows x 11 columns]

# %%
datetimefix = ufodf['datetime']
datetimefix = pd.DataFrame(datetimefix.str.split("/",expand=True))
datetimefix = datetimefix[2]
datetimefix = pd.DataFrame(datetimefix.str.split(expand=True))
datetimefix = pd.to_numeric(datetimefix[0])
datetimefix = pd.DataFrame(datetimefix)
datetimefix
# Out:
#           0
# 0      1949
# 1      1949
# 2      1955
# 3      1956
# 4      1960
# ...     ...
# 80327  2013
# 80328  2013
# 80329  2013
# 80330  2013
# 80331  2013
#
# [80332 rows x 1 columns]

# %%
ufodf = ufodf.join(datetimefix, how='left')
ufodf = ufodf.rename(columns={0: "year"})
ufodf
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 2                     20           20 seconds
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...                  ...                  ...
# 80327                600           10 minutes
# 80328               1200           20 minutes
# 80329               1200                 hour
# 80330                  5            5 seconds
# 80331               1020           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude   year
# 0      29.8830556  -97.941111  1949
# 1        29.38421  -98.581082  1949
# 2            53.2   -2.916667  1955
# 3      28.9783333  -96.645833  1956
# 4      21.4180556 -157.803611  1960
# ...           ...         ...   ...
# 80327  36.1658333  -86.784444  2013
# 80328  43.6136111 -116.202500  2013
# 80329  38.2972222 -122.284444  2013
# 80330  38.9011111  -77.265556  2013
# 80331  35.6527778  -97.477778  2013
#
# [80332 rows x 12 columns]

# %%
ufodf = ufodf.drop(ufodf[ufodf['year'] <= 2010].index)
ufodf = ufodf.drop('year', axis = 1)
ufodf.rename(columns={'duration (seconds)': 'duration in seconds', 'duration (hours/min)': 'duration in hours/min'}, inplace=True)
ufodf
# Out:
#                datetime                         city state country     shape  \
# 230    10/10/2011 00:00                         troy    ny      us  triangle
# 231    10/10/2011 01:00                   farmington    nm      us    circle
# 232    10/10/2011 02:00              prescott valley    az      us     other
# 233    10/10/2011 10:30                     ashville    ny      us    circle
# 234    10/10/2011 14:00  epsom (surrey) (uk/england)   NaN      gb      oval
# ...                 ...                          ...   ...     ...       ...
# 80327    9/9/2013 21:15                    nashville    tn      us     light
# 80328    9/9/2013 22:00                        boise    id      us    circle
# 80329    9/9/2013 22:00                         napa    ca      us     other
# 80330    9/9/2013 22:20                       vienna    va      us    circle
# 80331    9/9/2013 23:00                       edmond    ok      us     cigar
#
#       duration in seconds duration in hours/min  \
# 230                  7200               2 hours
# 231                   300             5 minutes
# 232                   300                 hours
# 233                    60              1 minute
# 234                   300                5 mins
# ...                   ...                   ...
# 80327                 600            10 minutes
# 80328                1200            20 minutes
# 80329                1200                  hour
# 80330                   5             5 seconds
# 80331                1020            17 minutes
#
#                                                 comments date posted  \
# 230    Red&#44 green &amp; orange blinking triangle f...  10/10/2011
# 231    Single reddish circle  in the sky that wasn&#3...   8/30/2013
# 232    Craft boomerang shape.2:00am duration hours.  ...  10/10/2011
# 233    Amber object in night sky during full moon&#44...  10/19/2011
# 234            Flying beer barrel shaped metallic object  12/12/2011
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude
# 230    42.7283333  -73.692222
# 231    36.7280556 -108.218056
# 232    34.6100000 -112.315000
# 233    42.0963889  -79.375833
# 234     51.316667   -0.266667
# ...           ...         ...
# 80327  36.1658333  -86.784444
# 80328  43.6136111 -116.202500
# 80329  38.2972222 -122.284444
# 80330  38.9011111  -77.265556
# 80331  35.6527778  -97.477778
#
# [21761 rows x 11 columns]

# %%
ufodf.to_csv("Resources/limited_ufo.csv")
